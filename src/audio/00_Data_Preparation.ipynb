# %% [markdown]
# The first step is always data preparation, in this file we will try to do this
# - Our Data (NSynth dataset) is in shambles, so we first need to merge different folders (train, test, validate) into one folder and generate a .csv file that will map each file into a class/label using examples.json
# - After getting our data sorted, we need to see the distribution of classes (how many audio files we have for each class).
# - We will then try to visualize our wav files (one file from each class/label)
#     - Time Series
#     - Fourier Transformers
#     - Filter Bank Coefficient
#     - Mel Frequency Cepstrum Coefficient
# - After visualizing our data, we can then decide how to normalize it.

# %% [markdown]
# # Step 1: Generate CSV File

# %%
# !python ../../utils/generate_audio_csv.py
# Out:
# python: can't open file 'C:\Users\Hakim\Documents\ENSET\IA_Avance\musical-instrument-classifier\utils\generate_audio_csv': [Errno 2] No such file or directory
